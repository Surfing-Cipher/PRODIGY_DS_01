# %% [markdown]
# ## Task-01
#
# ### 📌 Objective:
# Create a **bar chart** or **histogram** to visualize the distribution of a categorical or continuous variable, such as the distribution of ages or genders in a population.
#
# ### 📊 Sample Dataset:
# [World Bank Population Data](https://data.worldbank.org/indicator/SP.POP.TOTL)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path = "API_SP.POP.TOTL_DS2_en_csv_v2_76253.csv"
df = pd.read_csv(file_path, skiprows=4)  # Skipping metadata rows

# %%
df.info()  # Get column details
df.columns  # See available column names
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 68 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    266 non-null    object
#  1   Country Code    266 non-null    object
#  2   Indicator Name  266 non-null    object
#  3   Indicator Code  266 non-null    object
#  4   1960            264 non-null    float64
#  5   1961            264 non-null    float64
#  6   1962            264 non-null    float64
#  7   1963            264 non-null    float64
#  8   1964            264 non-null    float64
#  9   1965            264 non-null    float64
#  10  1966            264 non-null    float64
#  11  1967            264 non-null    float64
#  12  1968            264 non-null    float64
#  13  1969            264 non-null    float64
#  14  1970            264 non-null    float64
#  15  1971            264 non-null    float64
#  16  1972            264 non-null    float64
#  17  1973            264 non-null    float64
#  18  1974            264 non-null    float64
#  19  1975            264 non-null    float64
#  20  1976            264 non-null    float64
#  21  1977            264 non-null    float64
#  22  1978            264 non-null    float64
#  23  1979            264 non-null    float64
#  24  1980            264 non-null    float64
#  25  1981            264 non-null    float64
#  26  1982            264 non-null    float64
#  27  1983            264 non-null    float64
#  28  1984            264 non-null    float64
#  29  1985            264 non-null    float64
#  30  1986            264 non-null    float64
#  31  1987            264 non-null    float64
#  32  1988            264 non-null    float64
#  33  1989            264 non-null    float64
#  34  1990            265 non-null    float64
#  35  1991            265 non-null    float64
#  36  1992            265 non-null    float64
#  37  1993            265 non-null    float64
#  38  1994            265 non-null    float64
#  39  1995            265 non-null    float64
#  40  1996            265 non-null    float64
#  41  1997            265 non-null    float64
#  42  1998            265 non-null    float64
#  43  1999            265 non-null    float64
#  44  2000            265 non-null    float64
#  45  2001            265 non-null    float64
#  46  2002            265 non-null    float64
#  47  2003            265 non-null    float64
#  48  2004            265 non-null    float64
#  49  2005            265 non-null    float64
#  50  2006            265 non-null    float64
#  51  2007            265 non-null    float64
#  52  2008            265 non-null    float64
#  53  2009            265 non-null    float64
#  54  2010            265 non-null    float64
#  55  2011            265 non-null    float64
#  56  2012            265 non-null    float64
#  57  2013            265 non-null    float64
#  58  2014            265 non-null    float64
#  59  2015            265 non-null    float64
#  60  2016            265 non-null    float64
#  61  2017            265 non-null    float64
#  62  2018            265 non-null    float64
#  63  2019            265 non-null    float64
#  64  2020            265 non-null    float64
#  65  2021            265 non-null    float64
#  66  2022            265 non-null    float64
#  67  2023            265 non-null    float64
# dtypes: float64(64), object(4)
# memory usage: 141.4+ KB
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022',
#        '2023'],
#       dtype='object')

# %%
# Load the country metadata
meta_country = pd.read_csv("Metadata_Country_API_SP.POP.TOTL_DS2_en_csv_v2_76253.csv")
# Load the indicator metadata
meta_indicator = pd.read_csv("Metadata_Indicator_API_SP.POP.TOTL_DS2_en_csv_v2_76253.csv")

# %%
print(meta_country.columns)
print(meta_indicator.columns)
# Out:
# Index(['Country Code', 'Region', 'IncomeGroup', 'SpecialNotes', 'TableName',
#        'Unnamed: 5'],
#       dtype='object')
# Index(['INDICATOR_CODE', 'INDICATOR_NAME', 'SOURCE_NOTE',
#        'SOURCE_ORGANIZATION', 'Unnamed: 4'],
#       dtype='object')

# %%
#dropping empty data columns
meta_country = meta_country.drop(columns=["Unnamed: 5"], errors="ignore")
meta_indicator = meta_indicator.drop(columns=["Unnamed: 4"], errors="ignore")
df = df.drop(columns=["Unnamed: 68"], errors="ignore")

# %%
print(df.isnull().sum())  # Check missing values per column
# Out:
# Country Name      0
# Country Code      0
# Indicator Name    0
# Indicator Code    0
# 1960              2
#                  ..
# 2019              1
# 2020              1
# 2021              1
# 2022              1
# 2023              1
# Length: 68, dtype: int64

# %%
#since meta provides us with smaller details we'll merge them to make our population dataset more robust
df = df.merge(meta_country, on="Country Code", how="left")
df = df.merge(meta_indicator, left_on="Indicator Code", right_on="INDICATOR_CODE", how="left")

# %%
df = df.drop(columns=["INDICATOR_CODE", "SpecialNotes"], errors="ignore")

# %%
print(df.isnull().sum())
# Out:
# Country Name            0
# Country Code            0
# Indicator Name          0
# Indicator Code          0
# 1960                    2
#                        ..
# IncomeGroup            50
# TableName               1
# INDICATOR_NAME          0
# SOURCE_NOTE             0
# SOURCE_ORGANIZATION     0
# Length: 74, dtype: int64

# %%
df[df["IncomeGroup"].isnull()]
# Out:
#                                           Country Name Country Code  \
# 1                          Africa Eastern and Southern          AFE
# 3                           Africa Western and Central          AFW
# 7                                           Arab World          ARB
# 36                      Central Europe and the Baltics          CEB
# 49                              Caribbean small states          CSS
# 61         East Asia & Pacific (excluding high income)          EAP
# 62                          Early-demographic dividend          EAR
# 63                                 East Asia & Pacific          EAS
# 64       Europe & Central Asia (excluding high income)          ECA
# 65                               Europe & Central Asia          ECS
# 68                                           Euro area          EMU
# 73                                      European Union          EUU
# 74            Fragile and conflict affected situations          FCS
# 95                                         High income          HIC
# 98              Heavily indebted poor countries (HIPC)          HPC
# 102                                          IBRD only          IBD
# 103                                   IDA & IBRD total          IBT
# 104                                          IDA total          IDA
# 105                                          IDA blend          IDB
# 107                                           IDA only          IDX
# 110                                     Not classified          INX
# 128  Latin America & Caribbean (excluding high income)          LAC
# 134                          Latin America & Caribbean          LCN
# 135       Least developed countries: UN classification          LDC
# 136                                         Low income          LIC
# 139                                Lower middle income          LMC
# 140                                Low & middle income          LMY
# 142                          Late-demographic dividend          LTE
# 153                         Middle East & North Africa          MEA
# 156                                      Middle income          MIC
# 161  Middle East & North Africa (excluding high inc...          MNA
# 170                                      North America          NAC
# 181                                       OECD members          OED
# 183                                 Other small states          OSS
# 191                           Pre-demographic dividend          PRE
# 197                        Pacific island small states          PSS
# 198                          Post-demographic dividend          PST
# 204                                         South Asia          SAS
# 215         Sub-Saharan Africa (excluding high income)          SSA
# 217                                 Sub-Saharan Africa          SSF
# 218                                       Small states          SST
# 230         East Asia & Pacific (IDA & IBRD countries)          TEA
# 231       Europe & Central Asia (IDA & IBRD countries)          TEC
# 236  Latin America & the Caribbean (IDA & IBRD coun...          TLA
# 238  Middle East & North Africa (IDA & IBRD countries)          TMN
# 240                            South Asia (IDA & IBRD)          TSA
# 241          Sub-Saharan Africa (IDA & IBRD countries)          TSS
# 249                                Upper middle income          UMC
# 254                                      Venezuela, RB          VEN
# 259                                              World          WLD
#
#         Indicator Name Indicator Code          1960          1961  \
# 1    Population, total    SP.POP.TOTL  1.300721e+08  1.335349e+08
# 3    Population, total    SP.POP.TOTL  9.763092e+07  9.970667e+07
# 7    Population, total    SP.POP.TOTL  9.154085e+07  9.393168e+07
# 36   Population, total    SP.POP.TOTL  9.140176e+07  9.223274e+07
# 49   Population, total    SP.POP.TOTL  1.713405e+06  1.751114e+06
# 61   Population, total    SP.POP.TOTL  8.959615e+08  8.955346e+08
# 62   Population, total    SP.POP.TOTL  9.689094e+08  9.941768e+08
# 63   Population, total    SP.POP.TOTL  1.042838e+09  1.044750e+09
# 64   Population, total    SP.POP.TOTL  1.288105e+08  1.316179e+08
# 65   Population, total    SP.POP.TOTL  6.678878e+08  6.755500e+08
# 68   Population, total    SP.POP.TOTL  2.701490e+08  2.724730e+08
# 73   Population, total    SP.POP.TOTL  3.577109e+08  3.606830e+08
# 74   Population, total    SP.POP.TOTL  2.454465e+08  2.507488e+08
# 95   Population, total    SP.POP.TOTL  9.069501e+08  9.180728e+08
# 98   Population, total    SP.POP.TOTL  1.636505e+08  1.676349e+08
# 102  Population, total    SP.POP.TOTL  1.893701e+09  1.915613e+09
# 103  Population, total    SP.POP.TOTL  2.289188e+09  2.321079e+09
# 104  Population, total    SP.POP.TOTL  3.954874e+08  4.054661e+08
# 105  Population, total    SP.POP.TOTL  1.208018e+08  1.238786e+08
# 107  Population, total    SP.POP.TOTL  2.746856e+08  2.815875e+08
# 110  Population, total    SP.POP.TOTL           NaN           NaN
# 128  Population, total    SP.POP.TOTL  1.941834e+08  1.996764e+08
# 134  Population, total    SP.POP.TOTL  2.186247e+08  2.247373e+08
# 135  Population, total    SP.POP.TOTL  2.450486e+08  2.509849e+08
# 136  Population, total    SP.POP.TOTL  1.361257e+08  1.393553e+08
# 139  Population, total    SP.POP.TOTL  8.190472e+08  8.396491e+08
# 140  Population, total    SP.POP.TOTL  2.106419e+09  2.136241e+09
# 142  Population, total    SP.POP.TOTL  1.094880e+09  1.096959e+09
# 153  Population, total    SP.POP.TOTL  1.031890e+08  1.059333e+08
# 156  Population, total    SP.POP.TOTL  1.970293e+09  1.996885e+09
# 161  Population, total    SP.POP.TOTL  9.713870e+07  9.966088e+07
# 170  Population, total    SP.POP.TOTL  1.986226e+08  2.020051e+08
# 181  Population, total    SP.POP.TOTL  8.095807e+08  8.207973e+08
# 183  Population, total    SP.POP.TOTL  5.458853e+06  5.547310e+06
# 191  Population, total    SP.POP.TOTL  1.889203e+08  1.933427e+08
# 197  Population, total    SP.POP.TOTL  9.121200e+05  9.382440e+05
# 198  Population, total    SP.POP.TOTL  7.563794e+08  7.654435e+08
# 204  Population, total    SP.POP.TOTL  5.626637e+08  5.765523e+08
# 215  Population, total    SP.POP.TOTL  2.276613e+08  2.331987e+08
# 217  Population, total    SP.POP.TOTL  2.277030e+08  2.332416e+08
# 218  Population, total    SP.POP.TOTL  8.084378e+06  8.236668e+06
# 230  Population, total    SP.POP.TOTL  8.842525e+08  8.835582e+08
# 231  Population, total    SP.POP.TOTL  3.087594e+08  3.134836e+08
# 236  Population, total    SP.POP.TOTL  2.086711e+08  2.145827e+08
# 238  Population, total    SP.POP.TOTL  9.713870e+07  9.966088e+07
# 156  5.758609e+09  5.807623e+09  5.851866e+09  5.896643e+09
# 161  4.184613e+08  4.249806e+08  4.322291e+08  4.401182e+08
# 170  3.696200e+08  3.703535e+08  3.722752e+08  3.750774e+08
# 181  1.370014e+09  1.371769e+09  1.378507e+09  1.385723e+09
# 183  1.388410e+07  1.404080e+07  1.421772e+07  1.441192e+07
# 191  9.986243e+08  1.024960e+09  1.051202e+09  1.078224e+09
# 197  2.595522e+06  2.625493e+06  2.656049e+06  2.689224e+06
# 198  1.117765e+09  1.117015e+09  1.117562e+09  1.119236e+09
# 204  1.895144e+09  1.914264e+09  1.932289e+09  1.951540e+09
# 215  1.168917e+09  1.198913e+09  1.229089e+09  1.259783e+09
# 217  1.169015e+09  1.199012e+09  1.229209e+09  1.259902e+09
# 218  1.957219e+07  1.977790e+07  2.000527e+07  2.025354e+07
# 230  2.095759e+09  2.102351e+09  2.107261e+09  2.111139e+09
# 231  4.639130e+08  4.637909e+08  4.614402e+08  4.590255e+08
# 236  6.300510e+08  6.338626e+08  6.378378e+08  6.423979e+08
# 238  4.136580e+08  4.200578e+08  4.271855e+08  4.349524e+08
# 240  1.895144e+09  1.914264e+09  1.932289e+09  1.951540e+09
# 241  1.169015e+09  1.199012e+09  1.229209e+09  1.259902e+09
# 249  2.792212e+09  2.803460e+09  2.810662e+09  2.816864e+09
# 254  2.844408e+07  2.823783e+07  2.821302e+07  2.830085e+07
# 259  7.856139e+09  7.921184e+09  7.989982e+09  8.061876e+09
#
#                         Region  IncomeGroup  \
# 1                          NaN          NaN
# 3                          NaN          NaN
# 7                          NaN          NaN
# 36                         NaN          NaN
# 49                         NaN          NaN
# 61                         NaN          NaN
# 62                         NaN          NaN
# 63                         NaN          NaN
# 64                         NaN          NaN
# 65                         NaN          NaN
# 68                         NaN          NaN
# 73                         NaN          NaN
# 74                         NaN          NaN
# 95                         NaN          NaN
# 98                         NaN          NaN
# 102                        NaN          NaN
# 103                        NaN          NaN
# 104                        NaN          NaN
# 105                        NaN          NaN
# 107                        NaN          NaN
# 110                        NaN          NaN
# 128                        NaN          NaN
# 134                        NaN          NaN
# 135                        NaN          NaN
# 136                        NaN          NaN
# 139                        NaN          NaN
# 140                        NaN          NaN
# 142                        NaN          NaN
# 153                        NaN          NaN
# 156                        NaN          NaN
# 161                        NaN          NaN
# 170                        NaN          NaN
# 181                        NaN          NaN
# 183                        NaN          NaN
# 191                        NaN          NaN
# 197                        NaN          NaN
# 198                        NaN          NaN
# 204                        NaN          NaN
# 215                        NaN          NaN
# 217                        NaN          NaN
# 218                        NaN          NaN
# 230                        NaN          NaN
# 231                        NaN          NaN
# 236                        NaN          NaN
# 238                        NaN          NaN
# 240                        NaN          NaN
# 241                        NaN          NaN
# 249                        NaN          NaN
# 254  Latin America & Caribbean          NaN
# 259                        NaN          NaN
#
#                                              TableName     INDICATOR_NAME  \
# 1                          Africa Eastern and Southern  Population, total
# 3                           Africa Western and Central  Population, total
# 7                                           Arab World  Population, total
# 36                      Central Europe and the Baltics  Population, total
# 49                              Caribbean small states  Population, total
# 61         East Asia & Pacific (excluding high income)  Population, total
# 62                          Early-demographic dividend  Population, total
# 63                                 East Asia & Pacific  Population, total
# 64       Europe & Central Asia (excluding high income)  Population, total
# 65                               Europe & Central Asia  Population, total
# 68                                           Euro area  Population, total
# 73                                      European Union  Population, total
# 74            Fragile and conflict affected situations  Population, total
# 95                                         High income  Population, total
# 98              Heavily indebted poor countries (HIPC)  Population, total
# 102                                          IBRD only  Population, total
# 103                                   IDA & IBRD total  Population, total
# 104                                          IDA total  Population, total
# 105                                          IDA blend  Population, total
# 107                                           IDA only  Population, total
# 110                                                NaN  Population, total
# 128  Latin America & Caribbean (excluding high income)  Population, total
# 134                          Latin America & Caribbean  Population, total
# 135       Least developed countries: UN classification  Population, total
# 136                                         Low income  Population, total
# 139                                Lower middle income  Population, total
# 140                                Low & middle income  Population, total
# 142                          Late-demographic dividend  Population, total
# 153                         Middle East & North Africa  Population, total
# 156                                      Middle income  Population, total
# 161  Middle East & North Africa (excluding high inc...  Population, total
# 170                                      North America  Population, total
# 181                                       OECD members  Population, total
# 183                                 Other small states  Population, total
# 191                           Pre-demographic dividend  Population, total
# 197                        Pacific island small states  Population, total
# 198                          Post-demographic dividend  Population, total
# 204                                         South Asia  Population, total
# 215         Sub-Saharan Africa (excluding high income)  Population, total
# 217                                 Sub-Saharan Africa  Population, total
# 218                                       Small states  Population, total
# 230                   East Asia & Pacific (IDA & IBRD)  Population, total
# 231                 Europe & Central Asia (IDA & IBRD)  Population, total
# 236             Latin America & Caribbean (IDA & IBRD)  Population, total
# 238            Middle East & North Africa (IDA & IBRD)  Population, total
# 240                            South Asia (IDA & IBRD)  Population, total
# 241                    Sub-Saharan Africa (IDA & IBRD)  Population, total
# 249                                Upper middle income  Population, total
# 254                                      Venezuela, RB  Population, total
# 259                                              World  Population, total
#
#                                            SOURCE_NOTE  \
# 1    Total population is based on the de facto defi...
# 3    Total population is based on the de facto defi...
# 7    Total population is based on the de facto defi...
# 36   Total population is based on the de facto defi...
# 49   Total population is based on the de facto defi...
# 61   Total population is based on the de facto defi...
# 62   Total population is based on the de facto defi...
# 63   Total population is based on the de facto defi...
# 64   Total population is based on the de facto defi...
# 65   Total population is based on the de facto defi...
# 68   Total population is based on the de facto defi...
# 73   Total population is based on the de facto defi...
# 74   Total population is based on the de facto defi...
# 95   Total population is based on the de facto defi...
# 98   Total population is based on the de facto defi...
# 102  Total population is based on the de facto defi...
# 103  Total population is based on the de facto defi...
# 104  Total population is based on the de facto defi...
# 105  Total population is based on the de facto defi...
# 107  Total population is based on the de facto defi...
# 110  Total population is based on the de facto defi...
# 128  Total population is based on the de facto defi...
# 134  Total population is based on the de facto defi...
# 135  Total population is based on the de facto defi...
# 136  Total population is based on the de facto defi...
# 139  Total population is based on the de facto defi...
# 140  Total population is based on the de facto defi...
# 142  Total population is based on the de facto defi...
# 153  Total population is based on the de facto defi...
# 156  Total population is based on the de facto defi...
# 161  Total population is based on the de facto defi...
# 170  Total population is based on the de facto defi...
# 181  Total population is based on the de facto defi...
# 183  Total population is based on the de facto defi...
# 191  Total population is based on the de facto defi...
# 197  Total population is based on the de facto defi...
# 198  Total population is based on the de facto defi...
# 204  Total population is based on the de facto defi...
# 215  Total population is based on the de facto defi...
# 217  Total population is based on the de facto defi...
# 218  Total population is based on the de facto defi...
# 230  Total population is based on the de facto defi...
# 231  Total population is based on the de facto defi...
# 236  Total population is based on the de facto defi...
# 238  Total population is based on the de facto defi...
# 240  Total population is based on the de facto defi...
# 241  Total population is based on the de facto defi...
# 249  Total population is based on the de facto defi...
# 254  Total population is based on the de facto defi...
# 259  Total population is based on the de facto defi...
#
#                                    SOURCE_ORGANIZATION
# 1    (1) United Nations Population Division. World ...
# 3    (1) United Nations Population Division. World ...
# 7    (1) United Nations Population Division. World ...
# 36   (1) United Nations Population Division. World ...
# 49   (1) United Nations Population Division. World ...
# 61   (1) United Nations Population Division. World ...
# 62   (1) United Nations Population Division. World ...
# 63   (1) United Nations Population Division. World ...
# 64   (1) United Nations Population Division. World ...
# 65   (1) United Nations Population Division. World ...
# 68   (1) United Nations Population Division. World ...
# 73   (1) United Nations Population Division. World ...
# 74   (1) United Nations Population Division. World ...
# 95   (1) United Nations Population Division. World ...
# 98   (1) United Nations Population Division. World ...
# 102  (1) United Nations Population Division. World ...
# 103  (1) United Nations Population Division. World ...
# 104  (1) United Nations Population Division. World ...
# 105  (1) United Nations Population Division. World ...
# 107  (1) United Nations Population Division. World ...
# 110  (1) United Nations Population Division. World ...
# 128  (1) United Nations Population Division. World ...
# 134  (1) United Nations Population Division. World ...
# 135  (1) United Nations Population Division. World ...
# 136  (1) United Nations Population Division. World ...
# 139  (1) United Nations Population Division. World ...
# 140  (1) United Nations Population Division. World ...
# 142  (1) United Nations Population Division. World ...
# 153  (1) United Nations Population Division. World ...
# 156  (1) United Nations Population Division. World ...
# 161  (1) United Nations Population Division. World ...
# 170  (1) United Nations Population Division. World ...
# 181  (1) United Nations Population Division. World ...
# 183  (1) United Nations Population Division. World ...
# 191  (1) United Nations Population Division. World ...
# 197  (1) United Nations Population Division. World ...
# 198  (1) United Nations Population Division. World ...
# 204  (1) United Nations Population Division. World ...
# 215  (1) United Nations Population Division. World ...
# 217  (1) United Nations Population Division. World ...
# 218  (1) United Nations Population Division. World ...
# 230  (1) United Nations Population Division. World ...
# 231  (1) United Nations Population Division. World ...
# 236  (1) United Nations Population Division. World ...
# 238  (1) United Nations Population Division. World ...
# 240  (1) United Nations Population Division. World ...
# 241  (1) United Nations Population Division. World ...
# 249  (1) United Nations Population Division. World ...
# 254  (1) United Nations Population Division. World ...
# 259  (1) United Nations Population Division. World ...
#
# [50 rows x 74 columns]

# %%
#for population data 1960,... fill them with data from the next field
df = df.bfill(axis=1)

# %%
#filling with a placeholder because I dont to drop too much data
df["IncomeGroup"] = df["IncomeGroup"].fillna("Unknown")

# %%
#since tablename only has one missing value we'll use the placeholder again
df["TableName"] = df["TableName"].fillna("Unknown")

# %%
print(df.isnull().sum())
# Out:
# Country Name           0
# Country Code           0
# Indicator Name         0
# Indicator Code         0
# 1960                   0
#                       ..
# IncomeGroup            0
# TableName              0
# INDICATOR_NAME         0
# SOURCE_NOTE            0
# SOURCE_ORGANIZATION    0
# Length: 74, dtype: int64

# %%
plt.figure(figsize=(12, 6))

top_n = 10  # Display the top 10 categories (adjust as needed)
top_income_groups = df["IncomeGroup"].value_counts().nlargest(top_n).index
ax = sns.countplot(data=df, y="IncomeGroup", hue = "IncomeGroup", palette="viridis", order=top_income_groups, legend = False)

plt.title("Distribution of Countries by Top Income Groups")
plt.xlabel("Count of Countries")
plt.ylabel("Income Group")
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(population_data, bins=30, kde=True, color="orange")

plt.title("Population Distribution in 2023", fontsize=14, fontweight="bold")
plt.xlabel("Population", fontsize=12)
plt.ylabel("Frequency", fontsize=12)

plt.xscale("log")  # Handle large differences in population
plt.grid(axis="y", linestyle="--", alpha=0.7)

plt.show()

# %% [markdown]
# ### Why Are We Doing This?
#
# - **Analyze global population trends** across different income levels.
# - **Identify growth patterns**—which income groups are expanding the fastest.
# - **Compare economic categories** and their demographic shifts over time.
#
# This insight is valuable for **policy-making, economic planning, and understanding global development trends**.
#
# ### Key Takeaways
#
# - **Some groups, like "IDA & IBRD total,"** show a significant population increase by 2023.
# - **"High income" groups remain relatively small** in total population.
# - **The world's total population continues to grow** across all income categories.

# %%
plt.figure(figsize=(12, 8))

# Select top 10 income groups based on total population in 2023
top_n = 10
top_income_groups = df.groupby("IncomeGroup")["2023"].sum().nlargest(top_n).index

filtered_df = df[df["IncomeGroup"].isin(top_income_groups)]

melted_df = filtered_df.melt(id_vars="IncomeGroup", value_vars=["2000", "2010", "2023"],
                             var_name="Year", value_name="Total Population")

sns.barplot(data=melted_df, y="IncomeGroup", x="Total Population", hue="Year", palette="viridis")

plt.title("Comparison of Population by Income Group (2000 vs 2010 vs 2023)", fontsize=14, fontweight="bold")
plt.xlabel("Total Population", fontsize=12)
plt.ylabel("Income Group", fontsize=12)
plt.legend(title="Year")
plt.grid(axis="x", linestyle="--", alpha=0.7)

plt.show()

# %% [markdown]
# ### Why Are We Doing This?
#
# - **Understand how population distribution has evolved** over time (2000, 2010, 2023).
# - **Identify shifts in demographic concentration**—are populations becoming more evenly distributed or clustered?
# - **Use logarithmic scaling** to handle extreme differences in population sizes across countries.
#
# This visualization helps policymakers, researchers, and analysts track **global demographic trends** and their implications.
#
# ### Key Takeaways
#
# - **Most populations are concentrated at the lower end**, but a few countries have extremely high populations.
# - **The overall shape remains similar**, but the 2023 curve slightly shifts, indicating population growth.
# - **The KDE (smoothed line) helps reveal distribution patterns** that raw histograms might obscure.

# %%
plt.figure(figsize=(12, 7))

# More distinct greenish shades
colors = ["#a8ddb5", "#43a2ca", "#0868ac"]

# Line styles for KDE
line_styles = ['-', '--', ':']

# Plot histograms with adjusted settings
for i, year in enumerate(["2000", "2010", "2023"]):
    sns.histplot(df[year].dropna(), bins=30, color=colors[i], alpha=0.7, label=year,
                 kde=True, kde_kws={}, line_kws={'linestyle': line_styles[i], 'linewidth': 2}, edgecolor = 'black', linewidth = 0.5) #moved linestyle to line_kws.

plt.title("Comparison of Population Distribution (2000 vs 2010 vs 2023)", fontsize=14, fontweight="bold")
plt.xlabel("Population", fontsize=12)
plt.ylabel("Frequency", fontsize=12)

plt.xscale("log")
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.legend(title="Year")

# Optional: Add a light gray background
plt.style.use('ggplot') # or plt.gca().set_facecolor('#f0f0f0')

plt.show()
